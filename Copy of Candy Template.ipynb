# %% [markdown]
# # Project: cleanning - [candy data]
# ### this notebook is for educational purpose . in this notebook we will do some cleanning
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">wrangling</a></li>
#
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# ### Dataset Description
#
# > i will go through candy data 2017 , this data has :
# - Internal_ID
# - Q1-Going Out?: Are you actually going trick or treating yourself? "has values `Yes or No`"
# - Q2-Gender: It has four different options, `Femal ,Male ,Other ,I'd rather not say`
# - Q3-Age: Numerical field
# - Q4-Country: Text Field, but users have written their own version of the names. Example, for America, there are entries such as USA, us, US, America so we should consider that while cleanning
# - Q5-State/Province: Text Field, but users have written their own version of the names. Same as the country data.
# - Q6-Joy Or Despair: All kinds of chocolate bars are the questions with three distinct options to choose from (Joy, Meh, Despair).
# - Q7-Joy Other: Text Field to write items not included above that give you JOY. Lots of missing values.
# - Q8-Despair Other: Text Field ti write items not included above that give you DESPAIR. Lots of missing values.
# - Q9-Other Comments: Text Field. Lots of missing values.
# - Q10-Dress: Binary field. Missing values present
# - Unnamed: 113
# - Q11-Day: Binary Answer Field. Missing values present

# %% [markdown]
# # 1- import packages and load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
import numpy as np
import pandas as pd
import re
from fuzzywuzzy import process
from fuzzywuzzy import fuzz
# Out:
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
df = pd.read_excel('/content/drive/MyDrive/ieeetasksfordatascience/Candy Task/candyhierarchy2017.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
#
#
# ### General Properties

# %% [markdown]
# # 2- show some general properties for the data

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Q6 | Any full-sized candy bar Q6 | Black Jacks Q6 | Bonkers (the candy)  \
# 0                           NaN              NaN                      NaN
# 1                           JOY              MEH                  DESPAIR
# 2                           NaN              NaN                      NaN
# 3                           JOY              MEH                      MEH
# 4                           JOY          DESPAIR                      MEH
#
#   Q6 | Bonkers (the board game) Q6 | Bottle Caps Q6 | Box'o'Raisins  \
# 0                           NaN              NaN                NaN
# 1                       DESPAIR          DESPAIR            DESPAIR
# 2                           NaN              NaN                NaN
# 3                       DESPAIR              MEH            DESPAIR
# 4                       DESPAIR              MEH            DESPAIR
#
#   Q6 | Broken glow stick Q6 | Butterfinger Q6 | Cadbury Creme Eggs  \
# 0                    NaN               NaN                     NaN
# 1                DESPAIR           DESPAIR                     MEH
# 2                    NaN               NaN                     NaN
# 3                DESPAIR               MEH                     MEH
# 4                DESPAIR               MEH                     MEH
#
#   Q6 | Candy Corn  \
# 0             NaN
# 1             MEH
# 2             NaN
# 3         DESPAIR
# 4         DESPAIR
#
#   Q6 | Candy that is clearly just the stuff given out for free at restaurants  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Q6 | Caramellos Q6 | Cash, or other forms of legal tender Q6 | Chardonnay  \
# 0             NaN                                       NaN             NaN
# 1             MEH                                       JOY             MEH
# 2             NaN                                       NaN             NaN
# 3             MEH                                       JOY             MEH
# 4             JOY                                       MEH             JOY
#
#   Q6 | Chick-o-Sticks (we don’t know what that is) Q6 | Chiclets  \
# 0                                              NaN           NaN
# 1                                          DESPAIR       DESPAIR
# 2                                              NaN           NaN
# 3                                              JOY           MEH
# 4                                          DESPAIR       DESPAIR
#
#   Q6 | Coffee Crisp Q6 | Creepy Religious comics/Chick Tracts  \
# 0               NaN                                       NaN
# 1           DESPAIR                                   DESPAIR
# 2               NaN                                       NaN
# 3           DESPAIR                                   DESPAIR
# 4               MEH                                   DESPAIR
#
#   Q6 | Dental paraphenalia Q6 | Dots Q6 | Dove Bars Q6 | Fuzzy Peaches  \
# 0                      NaN       NaN            NaN                NaN
# 1                  DESPAIR       MEH            JOY            DESPAIR
# 2                      NaN       NaN            NaN                NaN
# 3                  DESPAIR       JOY            JOY                MEH
# 4                  DESPAIR       MEH            JOY            DESPAIR
#
#   Q6 | Generic Brand Acetaminophen Q6 | Glow sticks Q6 | Goo Goo Clusters  \
# 0                              NaN              NaN                   NaN
# 1                          DESPAIR          DESPAIR               DESPAIR
# 2                              NaN              NaN                   NaN
# 3                              MEH              JOY                   JOY
# 4                          DESPAIR          DESPAIR                   MEH
#
#   Q6 | Good N' Plenty Q6 | Gum from baseball cards  \
# 0                 NaN                          NaN
# 1                 MEH                      DESPAIR
# 2                 NaN                          NaN
# 3                 MEH                      DESPAIR
# 4                 MEH                      DESPAIR
#
#   Q6 | Gummy Bears straight up Q6 | Hard Candy Q6 | Healthy Fruit  \
# 0                          NaN             NaN                NaN
# 1                          MEH             MEH            DESPAIR
# 2                          NaN             NaN                NaN
# 3                          JOY             MEH                MEH
# 4                          JOY             MEH            DESPAIR
#
#   Q6 | Heath Bar Q6 | Hershey's Dark Chocolate Q6 | Hershey’s Milk Chocolate  \
# 0            NaN                           NaN                           NaN
# 1            MEH                           JOY                           JOY
# 2            NaN                           NaN                           NaN
# 3        DESPAIR                           MEH                           MEH
# 4        DESPAIR                           JOY                           MEH
#
#   Q6 | Hershey's Kisses Q6 | Hugs (actual physical hugs)  \
# 0                   NaN                              NaN
# 1                   MEH                          DESPAIR
# 2                   NaN                              NaN
# 3                   MEH                              MEH
# 4                   MEH                          DESPAIR
#
#   Q6 | Jolly Rancher (bad flavor) Q6 | Jolly Ranchers (good flavor)  \
# 0                             NaN                               NaN
# 1                         DESPAIR                               MEH
# 2                             NaN                               NaN
# 3                             MEH                               MEH
# 4                             MEH                               JOY
#
#   Q6 | JoyJoy (Mit Iodine!) Q6 | Junior Mints Q6 | Senior Mints  \
# 0                       NaN               NaN               NaN
# 1                   DESPAIR           DESPAIR           DESPAIR
# 2                       NaN               NaN               NaN
# 3                   DESPAIR           DESPAIR           DESPAIR
# 4                       MEH               JOY           DESPAIR
#
#   Q6 | Kale smoothie Q6 | Kinder Happy Hippo Q6 | Kit Kat Q6 | LaffyTaffy  \
# 0                NaN                     NaN          NaN             NaN
# 1            DESPAIR                 DESPAIR          JOY         DESPAIR
# 2                NaN                     NaN          NaN             NaN
# 3            DESPAIR                     MEH          MEH             JOY
# 4            DESPAIR                     JOY          JOY             JOY
#
#   Q6 | LemonHeads Q6 | Licorice (not black) Q6 | Licorice (yes black)  \
# 0             NaN                       NaN                       NaN
# 1             MEH                       MEH                       JOY
# 2             NaN                       NaN                       NaN
# 3             JOY                       MEH                       JOY
# 4             JOY                       MEH                   DESPAIR
#
#   Q6 | Lindt Truffle Q6 | Lollipops Q6 | Mars Q6 | Maynards Q6 | Mike and Ike  \
# 0                NaN            NaN       NaN           NaN               NaN
# 1                MEH        DESPAIR   DESPAIR       DESPAIR               MEH
# 2                NaN            NaN       NaN           NaN               NaN
# 3                JOY        DESPAIR       JOY           MEH               MEH
# 4                JOY            MEH       MEH       DESPAIR               MEH
#
#   Q6 | Milk Duds Q6 | Milky Way Q6 | Regular M&Ms Q6 | Peanut M&M’s  \
# 0            NaN            NaN               NaN               NaN
# 1            MEH            JOY               JOY               MEH
# 2            NaN            NaN               NaN               NaN
# 3        DESPAIR            JOY               MEH               JOY
# 4            MEH            JOY               JOY               JOY
#
#   Q6 | Blue M&M's Q6 | Red M&M's Q6 | Green Party M&M's  \
# 0             NaN            NaN                    NaN
# 1             JOY            JOY                    JOY
# 2             NaN            NaN                    NaN
# 3             MEH            MEH                    MEH
# 4             JOY            JOY                    JOY
#
#   Q6 | Independent M&M's Q6 | Abstained from M&M'ing. Q6 | Minibags of chips  \
# 0                    NaN                          NaN                    NaN
# 1                    JOY                      DESPAIR                DESPAIR
# 2                    NaN                          NaN                    NaN
# 3                    MEH                          MEH                DESPAIR
# 4                    JOY                          MEH                DESPAIR
#
#   Q6 | Mint Kisses Q6 | Mint Juleps Q6 | Mr. Goodbar Q6 | Necco Wafers  \
# 0              NaN              NaN              NaN               NaN
# 1              MEH          DESPAIR          DESPAIR           DESPAIR
# 2              NaN              NaN              NaN               NaN
# 3          DESPAIR              MEH              MEH           DESPAIR
# 4              JOY              JOY              MEH           DESPAIR
#
#   Q6 | Nerds Q6 | Nestle Crunch Q6 | Now'n'Laters Q6 | Peeps Q6 | Pencils  \
# 0        NaN                NaN               NaN        NaN          NaN
# 1    DESPAIR                JOY           DESPAIR    DESPAIR      DESPAIR
# 2        NaN                NaN               NaN        NaN          NaN
# 3        MEH                MEH               MEH    DESPAIR      DESPAIR
# 4        JOY                JOY               JOY        MEH      DESPAIR
#
#   Q6 | Pixy Stix Q6 | Real Housewives of Orange County Season 9 Blue-Ray  \
# 0            NaN                                                NaN
# 1        DESPAIR                                            DESPAIR
# 2            NaN                                                NaN
# 3        DESPAIR                                            DESPAIR
# 4            JOY                                            DESPAIR
#
#   Q6 | Reese’s Peanut Butter Cups Q6 | Reese's Pieces Q6 | Reggie Jackson Bar  \
# 0                             NaN                 NaN                     NaN
# 1                             JOY                 JOY                 DESPAIR
# 2                             NaN                 NaN                     NaN
# 3                             JOY                 MEH                     MEH
# 4                             JOY                 JOY                     MEH
#
#   Q6 | Rolos Q6 | Sandwich-sized bags filled with BooBerry Crunch  \
# 0        NaN                                                NaN
# 1        JOY                                            DESPAIR
# 2        NaN                                                NaN
# 3        MEH                                            DESPAIR
# 4        JOY                                                NaN
#
#   Q6 | Skittles Q6 | Smarties (American) Q6 | Smarties (Commonwealth)  \
# 0           NaN                      NaN                          NaN
# 1       DESPAIR                  DESPAIR                      DESPAIR
# 2           NaN                      NaN                          NaN
# 3       DESPAIR                  DESPAIR                          MEH
# 4           JOY                      JOY                      DESPAIR
#
#   Q6 | Snickers Q6 | Sourpatch Kids (i.e. abominations of nature)  \
# 0           NaN                                               NaN
# 1           MEH                                           DESPAIR
# 2           NaN                                               NaN
# 3           JOY                                               MEH
# 4           NaN                                               MEH
#
#   Q6 | Spotted Dick Q6 | Starburst Q6 | Sweet Tarts Q6 | Swedish Fish  \
# 0               NaN            NaN              NaN               NaN
# 1           DESPAIR            MEH          DESPAIR               MEH
# 2               NaN            NaN              NaN               NaN
# 3           DESPAIR            MEH              MEH               JOY
# 4           DESPAIR            JOY              JOY               MEH
#
#   Q6 | Sweetums (a friend to diabetes) Q6 | Take 5 Q6 | Tic Tacs  \
# 0                                  NaN         NaN           NaN
# 1                              DESPAIR     DESPAIR       DESPAIR
# 2                                  NaN         NaN           NaN
# 3                                  MEH         JOY           MEH
# 4                              DESPAIR         MEH       DESPAIR
#
#   Q6 | Those odd marshmallow circus peanut things Q6 | Three Musketeers  \
# 0                                             NaN                   NaN
# 1                                         DESPAIR                   JOY
# 2                                             NaN                   NaN
# 3                                         DESPAIR               DESPAIR
# 4                                         DESPAIR                   JOY
#
#   Q6 | Tolberone something or other Q6 | Trail Mix Q6 | Twix  \
# 0                               NaN            NaN       NaN
# 1                               JOY        DESPAIR       JOY
# 2                               NaN            NaN       NaN
# 3                               JOY            MEH       JOY
# 4                               JOY        DESPAIR       JOY
#
#   Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                                MEH
#
#   Q6 | Vicodin Q6 | Whatchamacallit Bars Q6 | White Bread  \
# 0          NaN                       NaN              NaN
# 1      DESPAIR                   DESPAIR          DESPAIR
# 2          NaN                       NaN              NaN
# 3          JOY                       JOY          DESPAIR
# 4          JOY                       JOY          DESPAIR
#
#   Q6 | Whole Wheat anything Q6 | York Peppermint Patties  \
# 0                       NaN                          NaN
# 1                   DESPAIR                      DESPAIR
# 2                       NaN                          NaN
# 3                   DESPAIR                      DESPAIR
# 4                   DESPAIR                          JOY
#
#                                        Q7: JOY OTHER Q8: DESPAIR OTHER  \
# 0                                                NaN               NaN
# 1                                             Mounds               NaN
# 2                                                NaN               NaN
# 3  Reese's crispy crunchy bars, 5th avenue bars, ...               NaN
# 4                                                NaN               NaN
#
#                                   Q9: OTHER COMMENTS      Q10: DRESS  \
# 0                                                NaN             NaN
# 1  Bottom line is Twix is really the only candy w...  White and gold
# 2                                                NaN             NaN
# 3                             Raisins can go to hell  White and gold
# 4                                                NaN  White and gold
#
#   Unnamed: 113 Q11: DAY  Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  \
# 0          NaN      NaN                      NaN                   NaN
# 1          NaN   Sunday                      NaN                   1.0
# 2          NaN      NaN                      NaN                   NaN
# 3          NaN   Sunday                      NaN                   1.0
# 4          NaN   Friday                      NaN                   1.0
#
#    Q12: MEDIA [ESPN]  Q12: MEDIA [Yahoo] Click Coordinates (x, y)
# 0                NaN                 NaN                      NaN
# 1                NaN                 NaN                 (84, 25)
# 2                NaN                 NaN                      NaN
# 3                NaN                 NaN                 (75, 23)
# 4                NaN                 NaN                 (70, 10)

# %%
df.shape
# Out:
# (2460, 120)

# %%
df.iloc[:, :40].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Data columns (total 40 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   Internal ID                                                                            2460 non-null   int64
#  1   Q1: GOING OUT?                                                                         2350 non-null   object
#  2   Q2: GENDER                                                                             2419 non-null   object
#  3   Q3: AGE                                                                                2376 non-null   object
#  4   Q4: COUNTRY                                                                            2396 non-null   object
#  5   Q5: STATE, PROVINCE, COUNTY, ETC                                                       2360 non-null   object
#  6   Q6 | 100 Grand Bar                                                                     1713 non-null   object
#  7   Q6 | Anonymous brown globs that come in black and orange wrappers	(a.k.a. Mary Janes)  1726 non-null   object
#  8   Q6 | Any full-sized candy bar                                                          1788 non-null   object
#  9   Q6 | Black Jacks                                                                       1502 non-null   object
#  10  Q6 | Bonkers (the candy)                                                               1468 non-null   object
#  11  Q6 | Bonkers (the board game)                                                          1454 non-null   object
#  12  Q6 | Bottle Caps                                                                       1695 non-null   object
#  13  Q6 | Box'o'Raisins                                                                     1772 non-null   object
#  14  Q6 | Broken glow stick                                                                 1754 non-null   object
#  15  Q6 | Butterfinger                                                                      1778 non-null   object
#  16  Q6 | Cadbury Creme Eggs                                                                1777 non-null   object
#  17  Q6 | Candy Corn                                                                        1782 non-null   object
#  18  Q6 | Candy that is clearly just the stuff given out for free at restaurants            1769 non-null   object
#  19  Q6 | Caramellos                                                                        1708 non-null   object
#  20  Q6 | Cash, or other forms of legal tender                                              1780 non-null   object
#  21  Q6 | Chardonnay                                                                        1717 non-null   object
#  22  Q6 | Chick-o-Sticks (we don’t know what that is)                                       1514 non-null   object
#  23  Q6 | Chiclets                                                                          1749 non-null   object
#  24  Q6 | Coffee Crisp                                                                      1607 non-null   object
#  25  Q6 | Creepy Religious comics/Chick Tracts                                              1756 non-null   object
#  26  Q6 | Dental paraphenalia                                                               1768 non-null   object
#  27  Q6 | Dots                                                                              1731 non-null   object
#  28  Q6 | Dove Bars                                                                         1758 non-null   object
#  29  Q6 | Fuzzy Peaches                                                                     1637 non-null   object
#  30  Q6 | Generic Brand Acetaminophen                                                       1729 non-null   object
#  31  Q6 | Glow sticks                                                                       1763 non-null   object
#  32  Q6 | Goo Goo Clusters                                                                  1581 non-null   object
#  33  Q6 | Good N' Plenty                                                                    1726 non-null   object
#  34  Q6 | Gum from baseball cards                                                           1744 non-null   object
#  35  Q6 | Gummy Bears straight up                                                           1763 non-null   object
#  36  Q6 | Hard Candy                                                                        1765 non-null   object
#  37  Q6 | Healthy Fruit                                                                     1766 non-null   object
#  38  Q6 | Heath Bar                                                                         1748 non-null   object
#  39  Q6 | Hershey's Dark Chocolate                                                          1787 non-null   object
# dtypes: int64(1), object(39)
# memory usage: 768.9+ KB

# %%
df.iloc[:, 40:81].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Data columns (total 41 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Q6 | Hershey’s Milk Chocolate                            1788 non-null   object
#  1   Q6 | Hershey's Kisses                                    1782 non-null   object
#  2   Q6 | Hugs (actual physical hugs)                         1747 non-null   object
#  3   Q6 | Jolly Rancher (bad flavor)                          1766 non-null   object
#  4   Q6 | Jolly Ranchers (good flavor)                        1765 non-null   object
#  5   Q6 | JoyJoy (Mit Iodine!)                                1434 non-null   object
#  6   Q6 | Junior Mints                                        1762 non-null   object
#  7   Q6 | Senior Mints                                        1518 non-null   object
#  8   Q6 | Kale smoothie                                       1716 non-null   object
#  9   Q6 | Kinder Happy Hippo                                  1515 non-null   object
#  10  Q6 | Kit Kat                                             1786 non-null   object
#  11  Q6 | LaffyTaffy                                          1724 non-null   object
#  12  Q6 | LemonHeads                                          1730 non-null   object
#  13  Q6 | Licorice (not black)                                1774 non-null   object
#  14  Q6 | Licorice (yes black)                                1775 non-null   object
#  15  Q6 | Lindt Truffle                                       1742 non-null   object
#  16  Q6 | Lollipops                                           1769 non-null   object
#  17  Q6 | Mars                                                1735 non-null   object
#  18  Q6 | Maynards                                            1436 non-null   object
#  19  Q6 | Mike and Ike                                        1731 non-null   object
#  20  Q6 | Milk Duds                                           1767 non-null   object
#  21  Q6 | Milky Way                                           1772 non-null   object
#  22  Q6 | Regular M&Ms                                        1785 non-null   object
#  23  Q6 | Peanut M&M’s                                        1789 non-null   object
#  24  Q6 | Blue M&M's                                          1733 non-null   object
#  25  Q6 | Red M&M's                                           1731 non-null   object
#  26  Q6 | Green Party M&M's                                   1696 non-null   object
#  27  Q6 | Independent M&M's                                   1647 non-null   object
#  28  Q6 | Abstained from M&M'ing.                             1518 non-null   object
#  29  Q6 | Minibags of chips                                   1736 non-null   object
#  30  Q6 | Mint Kisses                                         1684 non-null   object
#  31  Q6 | Mint Juleps                                         1649 non-null   object
#  32  Q6 | Mr. Goodbar                                         1720 non-null   object
#  33  Q6 | Necco Wafers                                        1716 non-null   object
#  34  Q6 | Nerds                                               1737 non-null   object
#  35  Q6 | Nestle Crunch                                       1762 non-null   object
#  36  Q6 | Now'n'Laters                                        1643 non-null   object
#  37  Q6 | Peeps                                               1750 non-null   object
#  38  Q6 | Pencils                                             1751 non-null   object
#  39  Q6 | Pixy Stix                                           1738 non-null   object
#  40  Q6 | Real Housewives of Orange County Season 9 Blue-Ray  1707 non-null   object
# dtypes: object(41)
# memory usage: 788.1+ KB

# %%
df.iloc[:, 81:121].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Data columns (total 39 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   Q6 | Reese’s Peanut Butter Cups                                              1781 non-null   object
#  1   Q6 | Reese's Pieces                                                          1769 non-null   object
#  2   Q6 | Reggie Jackson Bar                                                      1446 non-null   object
#  3   Q6 | Rolos                                                                   1746 non-null   object
#  4   Q6 | Sandwich-sized bags filled with BooBerry Crunch                         1684 non-null   object
#  5   Q6 | Skittles                                                                1754 non-null   object
#  6   Q6 | Smarties (American)                                                     1735 non-null   object
#  7   Q6 | Smarties (Commonwealth)                                                 1559 non-null   object
#  8   Q6 | Snickers                                                                1770 non-null   object
#  9   Q6 | Sourpatch Kids (i.e. abominations of nature)                            1722 non-null   object
#  10  Q6 | Spotted Dick                                                            1578 non-null   object
#  11  Q6 | Starburst                                                               1767 non-null   object
#  12  Q6 | Sweet Tarts                                                             1752 non-null   object
#  13  Q6 | Swedish Fish                                                            1745 non-null   object
#  14  Q6 | Sweetums (a friend to diabetes)                                         1458 non-null   object
#  15  Q6 | Take 5                                                                  1543 non-null   object
#  16  Q6 | Tic Tacs                                                                1746 non-null   object
#  17  Q6 | Those odd marshmallow circus peanut things                              1724 non-null   object
#  18  Q6 | Three Musketeers                                                        1752 non-null   object
#  19  Q6 | Tolberone something or other                                            1754 non-null   object
#  20  Q6 | Trail Mix                                                               1752 non-null   object
#  21  Q6 | Twix                                                                    1770 non-null   object
#  22  Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein  1668 non-null   object
#  23  Q6 | Vicodin                                                                 1671 non-null   object
#  24  Q6 | Whatchamacallit Bars                                                    1637 non-null   object
#  25  Q6 | White Bread                                                             1703 non-null   object
#  26  Q6 | Whole Wheat anything                                                    1713 non-null   object
#  27  Q6 | York Peppermint Patties                                                 1755 non-null   object
#  28  Q7: JOY OTHER                                                                911 non-null    object
#  29  Q8: DESPAIR OTHER                                                            717 non-null    object
#  30  Q9: OTHER COMMENTS                                                           386 non-null    object
#  31  Q10: DRESS                                                                   1716 non-null   object
#  32  Unnamed: 113                                                                 9 non-null      object
#  33  Q11: DAY                                                                     1735 non-null   object
#  34  Q12: MEDIA [Daily Dish]                                                      85 non-null     float64
#  35  Q12: MEDIA [Science]                                                         1362 non-null   float64
#  36  Q12: MEDIA [ESPN]                                                            99 non-null     float64
#  37  Q12: MEDIA [Yahoo]                                                           67 non-null     float64
#  38  Click Coordinates (x, y)                                                     1605 non-null   object
# dtypes: float64(4), object(35)
# memory usage: 749.7+ KB

# %%
df.iloc[:, :40].isna().sum()
# Out:
# Internal ID                                                                                  0
# Q1: GOING OUT?                                                                             110
# Q2: GENDER                                                                                  41
# Q3: AGE                                                                                     84
# Q4: COUNTRY                                                                                 64
# Q5: STATE, PROVINCE, COUNTY, ETC                                                           100
# Q6 | 100 Grand Bar                                                                         747
# Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)     734
# Q6 | Any full-sized candy bar                                                              672
# Q6 | Black Jacks                                                                           958
# Q6 | Bonkers (the candy)                                                                   992
# Q6 | Bonkers (the board game)                                                             1006
# Q6 | Bottle Caps                                                                           765
# Q6 | Box'o'Raisins                                                                         688
# Q6 | Broken glow stick                                                                     706
# Q6 | Butterfinger                                                                          682
# Q6 | Cadbury Creme Eggs                                                                    683
# Q6 | Candy Corn                                                                            678
# Q6 | Candy that is clearly just the stuff given out for free at restaurants                691
# Q6 | Caramellos                                                                            752
# Q6 | Cash, or other forms of legal tender                                                  680
# Q6 | Chardonnay                                                                            743
# Q6 | Chick-o-Sticks (we don’t know what that is)                                           946
# Q6 | Chiclets                                                                              711
# Q6 | Coffee Crisp                                                                          853
# Q6 | Creepy Religious comics/Chick Tracts                                                  704
# Q6 | Dental paraphenalia                                                                   692
# Q6 | Dots                                                                                  729
# Q6 | Dove Bars                                                                             702
# Q6 | Fuzzy Peaches                                                                         823
# Q6 | Generic Brand Acetaminophen                                                           731
# Q6 | Glow sticks                                                                           697
# Q6 | Goo Goo Clusters                                                                      879
# Q6 | Good N' Plenty                                                                        734
# Q6 | Gum from baseball cards                                                               716
# Q6 | Gummy Bears straight up                                                               697
# Q6 | Hard Candy                                                                            695
# Q6 | Healthy Fruit                                                                         694
# Q6 | Heath Bar                                                                             712
# Q6 | Hershey's Dark Chocolate                                                              673
# dtype: int64

# %%
df.iloc[:, 40:81].isna().sum()
# Out:
# Q6 | Hershey’s Milk Chocolate                               672
# Q6 | Hershey's Kisses                                       678
# Q6 | Hugs (actual physical hugs)                            713
# Q6 | Jolly Rancher (bad flavor)                             694
# Q6 | Jolly Ranchers (good flavor)                           695
# Q6 | JoyJoy (Mit Iodine!)                                  1026
# Q6 | Junior Mints                                           698
# Q6 | Senior Mints                                           942
# Q6 | Kale smoothie                                          744
# Q6 | Kinder Happy Hippo                                     945
# Q6 | Kit Kat                                                674
# Q6 | LaffyTaffy                                             736
# Q6 | LemonHeads                                             730
# Q6 | Licorice (not black)                                   686
# Q6 | Licorice (yes black)                                   685
# Q6 | Lindt Truffle                                          718
# Q6 | Lollipops                                              691
# Q6 | Mars                                                   725
# Q6 | Maynards                                              1024
# Q6 | Mike and Ike                                           729
# Q6 | Milk Duds                                              693
# Q6 | Milky Way                                              688
# Q6 | Regular M&Ms                                           675
# Q6 | Peanut M&M’s                                           671
# Q6 | Blue M&M's                                             727
# Q6 | Red M&M's                                              729
# Q6 | Green Party M&M's                                      764
# Q6 | Independent M&M's                                      813
# Q6 | Abstained from M&M'ing.                                942
# Q6 | Minibags of chips                                      724
# Q6 | Mint Kisses                                            776
# Q6 | Mint Juleps                                            811
# Q6 | Mr. Goodbar                                            740
# Q6 | Necco Wafers                                           744
# Q6 | Nerds                                                  723
# Q6 | Nestle Crunch                                          698
# Q6 | Now'n'Laters                                           817
# Q6 | Peeps                                                  710
# Q6 | Pencils                                                709
# Q6 | Pixy Stix                                              722
# Q6 | Real Housewives of Orange County Season 9 Blue-Ray     753
# dtype: int64

# %%
df.iloc[:, 81:121].isna().sum()
# Out:
# Q6 | Reese’s Peanut Butter Cups                                                 679
# Q6 | Reese's Pieces                                                             691
# Q6 | Reggie Jackson Bar                                                        1014
# Q6 | Rolos                                                                      714
# Q6 | Sandwich-sized bags filled with BooBerry Crunch                            776
# Q6 | Skittles                                                                   706
# Q6 | Smarties (American)                                                        725
# Q6 | Smarties (Commonwealth)                                                    901
# Q6 | Snickers                                                                   690
# Q6 | Sourpatch Kids (i.e. abominations of nature)                               738
# Q6 | Spotted Dick                                                               882
# Q6 | Starburst                                                                  693
# Q6 | Sweet Tarts                                                                708
# Q6 | Swedish Fish                                                               715
# Q6 | Sweetums (a friend to diabetes)                                           1002
# Q6 | Take 5                                                                     917
# Q6 | Tic Tacs                                                                   714
# Q6 | Those odd marshmallow circus peanut things                                 736
# Q6 | Three Musketeers                                                           708
# Q6 | Tolberone something or other                                               706
# Q6 | Trail Mix                                                                  708
# Q6 | Twix                                                                       690
# Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein     792
# Q6 | Vicodin                                                                    789
# Q6 | Whatchamacallit Bars                                                       823
# Q6 | White Bread                                                                757
# Q6 | Whole Wheat anything                                                       747
# Q6 | York Peppermint Patties                                                    705
# Q7: JOY OTHER                                                                  1549
# Q8: DESPAIR OTHER                                                              1743
# Q9: OTHER COMMENTS                                                             2074
# Q10: DRESS                                                                      744
# Unnamed: 113                                                                   2451
# Q11: DAY                                                                        725
# Q12: MEDIA [Daily Dish]                                                        2375
# Q12: MEDIA [Science]                                                           1098
# Q12: MEDIA [ESPN]                                                              2361
# Q12: MEDIA [Yahoo]                                                             2393
# Click Coordinates (x, y)                                                        855
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 3- write summary about what you get form the above functions
# > #### tips : this summary can be about : if there is any missing values , if there a wrong data type , if there a wrong range of values , ....
# > #### Data has 2460 rows and 120 columns.
# > #### Data has zero duplicate.
# > #### Q7, Q8, Q9 and "Unnamed: 113" columns have a lot of missing values.
# > #### Q6 is the main column in survey.

# %% [markdown]
# # cleaning

# %% [markdown]
# ### 4- drop all the useless columns and  rows with too much NaN ,
# > tip : useless columns can be like `Internal ID`and can be also columns with too much NaN
# - rename columns for easy access

# %%
df.drop(["Internal ID", 'Q7: JOY OTHER', 'Q8: DESPAIR OTHER', 'Q9: OTHER COMMENTS', "Unnamed: 113", "Click Coordinates (x, y)"] , axis="columns", inplace=True)

# %%
df.rename(columns = {'Q1: GOING OUT?' : 'Going Out?',
                          'Q2: GENDER' : 'Gender',
                          'Q3: AGE': 'Age',
                          'Q4: COUNTRY' : 'Country',
                          'Q5: STATE, PROVINCE, COUNTY, ETC' : 'Area',
                          'Q10: DRESS' : 'Dress',
                          'Q11: DAY': 'Day',
                          'Q12: MEDIA [Daily Dish]' : 'DailyDish',
                          'Q12: MEDIA [Science]': 'Science',
                          'Q12: MEDIA [ESPN]' : 'ESPN',
                          'Q12: MEDIA [Yahoo]': 'Yahoo'}, inplace=True)

# %%
df.columns = [x for x in df.columns.str.replace("Q6 \| ",'')]
# Out:
# <ipython-input-17-0595057fd142>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = [x for x in df.columns.str.replace("Q6 \| ",'')]

# %%
df.head()
# Out:
#   Going Out? Gender  Age Country      Area 100 Grand Bar  \
# 0        NaN    NaN  NaN     NaN       NaN           NaN
# 1         No   Male   44    USA         NM           MEH
# 2        NaN   Male   49     USA  Virginia           NaN
# 3         No   Male   40      us        or           MEH
# 4         No   Male   23     usa  exton pa           JOY
#
#   Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Any full-sized candy bar Black Jacks Bonkers (the candy)  \
# 0                      NaN         NaN                 NaN
# 1                      JOY         MEH             DESPAIR
# 2                      NaN         NaN                 NaN
# 3                      JOY         MEH                 MEH
# 4                      JOY     DESPAIR                 MEH
#
#   Bonkers (the board game) Bottle Caps Box'o'Raisins Broken glow stick  \
# 0                      NaN         NaN           NaN               NaN
# 1                  DESPAIR     DESPAIR       DESPAIR           DESPAIR
# 2                      NaN         NaN           NaN               NaN
# 3                  DESPAIR         MEH       DESPAIR           DESPAIR
# 4                  DESPAIR         MEH       DESPAIR           DESPAIR
#
#   Butterfinger Cadbury Creme Eggs Candy Corn  \
# 0          NaN                NaN        NaN
# 1      DESPAIR                MEH        MEH
# 2          NaN                NaN        NaN
# 3          MEH                MEH    DESPAIR
# 4          MEH                MEH    DESPAIR
#
#   Candy that is clearly just the stuff given out for free at restaurants  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Caramellos Cash, or other forms of legal tender Chardonnay  \
# 0        NaN                                  NaN        NaN
# 1        MEH                                  JOY        MEH
# 2        NaN                                  NaN        NaN
# 3        MEH                                  JOY        MEH
# 4        JOY                                  MEH        JOY
#
#   Chick-o-Sticks (we don’t know what that is) Chiclets Coffee Crisp  \
# 0                                         NaN      NaN          NaN
# 1                                     DESPAIR  DESPAIR      DESPAIR
# 2                                         NaN      NaN          NaN
# 3                                         JOY      MEH      DESPAIR
# 4                                     DESPAIR  DESPAIR          MEH
#
#   Creepy Religious comics/Chick Tracts Dental paraphenalia Dots Dove Bars  \
# 0                                  NaN                 NaN  NaN       NaN
# 1                              DESPAIR             DESPAIR  MEH       JOY
# 2                                  NaN                 NaN  NaN       NaN
# 3                              DESPAIR             DESPAIR  JOY       JOY
# 4                              DESPAIR             DESPAIR  MEH       JOY
#
#   Fuzzy Peaches Generic Brand Acetaminophen Glow sticks Goo Goo Clusters  \
# 0           NaN                         NaN         NaN              NaN
# 1       DESPAIR                     DESPAIR     DESPAIR          DESPAIR
# 2           NaN                         NaN         NaN              NaN
# 3           MEH                         MEH         JOY              JOY
# 4       DESPAIR                     DESPAIR     DESPAIR              MEH
#
#   Good N' Plenty Gum from baseball cards Gummy Bears straight up Hard Candy  \
# 0            NaN                     NaN                     NaN        NaN
# 1            MEH                 DESPAIR                     MEH        MEH
# 2            NaN                     NaN                     NaN        NaN
# 3            MEH                 DESPAIR                     JOY        MEH
# 4            MEH                 DESPAIR                     JOY        MEH
#
#   Healthy Fruit Heath Bar Hershey's Dark Chocolate Hershey’s Milk Chocolate  \
# 0           NaN       NaN                      NaN                      NaN
# 1       DESPAIR       MEH                      JOY                      JOY
# 2           NaN       NaN                      NaN                      NaN
# 3           MEH   DESPAIR                      MEH                      MEH
# 4       DESPAIR   DESPAIR                      JOY                      MEH
#
#   Hershey's Kisses Hugs (actual physical hugs) Jolly Rancher (bad flavor)  \
# 0              NaN                         NaN                        NaN
# 1              MEH                     DESPAIR                    DESPAIR
# 2              NaN                         NaN                        NaN
# 3              MEH                         MEH                        MEH
# 4              MEH                     DESPAIR                        MEH
#
#   Jolly Ranchers (good flavor) JoyJoy (Mit Iodine!) Junior Mints Senior Mints  \
# 0                          NaN                  NaN          NaN          NaN
# 1                          MEH              DESPAIR      DESPAIR      DESPAIR
# 2                          NaN                  NaN          NaN          NaN
# 3                          MEH              DESPAIR      DESPAIR      DESPAIR
# 4                          JOY                  MEH          JOY      DESPAIR
#
#   Kale smoothie Kinder Happy Hippo Kit Kat LaffyTaffy LemonHeads  \
# 0           NaN                NaN     NaN        NaN        NaN
# 1       DESPAIR            DESPAIR     JOY    DESPAIR        MEH
# 2           NaN                NaN     NaN        NaN        NaN
# 3       DESPAIR                MEH     MEH        JOY        JOY
# 4       DESPAIR                JOY     JOY        JOY        JOY
#
#   Licorice (not black) Licorice (yes black) Lindt Truffle Lollipops     Mars  \
# 0                  NaN                  NaN           NaN       NaN      NaN
# 1                  MEH                  JOY           MEH   DESPAIR  DESPAIR
# 2                  NaN                  NaN           NaN       NaN      NaN
# 3                  MEH                  JOY           JOY   DESPAIR      JOY
# 4                  MEH              DESPAIR           JOY       MEH      MEH
#
#   Maynards Mike and Ike Milk Duds Milky Way Regular M&Ms Peanut M&M’s  \
# 0      NaN          NaN       NaN       NaN          NaN          NaN
# 1  DESPAIR          MEH       MEH       JOY          JOY          MEH
# 2      NaN          NaN       NaN       NaN          NaN          NaN
# 3      MEH          MEH   DESPAIR       JOY          MEH          JOY
# 4  DESPAIR          MEH       MEH       JOY          JOY          JOY
#
#   Blue M&M's Red M&M's Green Party M&M's Independent M&M's  \
# 0        NaN       NaN               NaN               NaN
# 1        JOY       JOY               JOY               JOY
# 2        NaN       NaN               NaN               NaN
# 3        MEH       MEH               MEH               MEH
# 4        JOY       JOY               JOY               JOY
#
#   Abstained from M&M'ing. Minibags of chips Mint Kisses Mint Juleps  \
# 0                     NaN               NaN         NaN         NaN
# 1                 DESPAIR           DESPAIR         MEH     DESPAIR
# 2                     NaN               NaN         NaN         NaN
# 3                     MEH           DESPAIR     DESPAIR         MEH
# 4                     MEH           DESPAIR         JOY         JOY
#
#   Mr. Goodbar Necco Wafers    Nerds Nestle Crunch Now'n'Laters    Peeps  \
# 0         NaN          NaN      NaN           NaN          NaN      NaN
# 1     DESPAIR      DESPAIR  DESPAIR           JOY      DESPAIR  DESPAIR
# 2         NaN          NaN      NaN           NaN          NaN      NaN
# 3         MEH      DESPAIR      MEH           MEH          MEH  DESPAIR
# 4         MEH      DESPAIR      JOY           JOY          JOY      MEH
#
#    Pencils Pixy Stix Real Housewives of Orange County Season 9 Blue-Ray  \
# 0      NaN       NaN                                                NaN
# 1  DESPAIR   DESPAIR                                            DESPAIR
# 2      NaN       NaN                                                NaN
# 3  DESPAIR   DESPAIR                                            DESPAIR
# 4  DESPAIR       JOY                                            DESPAIR
#
#   Reese’s Peanut Butter Cups Reese's Pieces Reggie Jackson Bar Rolos  \
# 0                        NaN            NaN                NaN   NaN
# 1                        JOY            JOY            DESPAIR   JOY
# 2                        NaN            NaN                NaN   NaN
# 3                        JOY            MEH                MEH   MEH
# 4                        JOY            JOY                MEH   JOY
#
#   Sandwich-sized bags filled with BooBerry Crunch Skittles  \
# 0                                             NaN      NaN
# 1                                         DESPAIR  DESPAIR
# 2                                             NaN      NaN
# 3                                         DESPAIR  DESPAIR
# 4                                             NaN      JOY
#
#   Smarties (American) Smarties (Commonwealth) Snickers  \
# 0                 NaN                     NaN      NaN
# 1             DESPAIR                 DESPAIR      MEH
# 2                 NaN                     NaN      NaN
# 3             DESPAIR                     MEH      JOY
# 4                 JOY                 DESPAIR      NaN
#
#   Sourpatch Kids (i.e. abominations of nature) Spotted Dick Starburst  \
# 0                                          NaN          NaN       NaN
# 1                                      DESPAIR      DESPAIR       MEH
# 2                                          NaN          NaN       NaN
# 3                                          MEH      DESPAIR       MEH
# 4                                          MEH      DESPAIR       JOY
#
#   Sweet Tarts Swedish Fish Sweetums (a friend to diabetes)   Take 5 Tic Tacs  \
# 0         NaN          NaN                             NaN      NaN      NaN
# 1     DESPAIR          MEH                         DESPAIR  DESPAIR  DESPAIR
# 2         NaN          NaN                             NaN      NaN      NaN
# 3         MEH          JOY                             MEH      JOY      MEH
# 4         JOY          MEH                         DESPAIR      MEH  DESPAIR
#
#   Those odd marshmallow circus peanut things Three Musketeers  \
# 0                                        NaN              NaN
# 1                                    DESPAIR              JOY
# 2                                        NaN              NaN
# 3                                    DESPAIR          DESPAIR
# 4                                    DESPAIR              JOY
#
#   Tolberone something or other Trail Mix Twix  \
# 0                          NaN       NaN  NaN
# 1                          JOY   DESPAIR  JOY
# 2                          NaN       NaN  NaN
# 3                          JOY       MEH  JOY
# 4                          JOY   DESPAIR  JOY
#
#   Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                                MEH
#
#    Vicodin Whatchamacallit Bars White Bread Whole Wheat anything  \
# 0      NaN                  NaN         NaN                  NaN
# 1  DESPAIR              DESPAIR     DESPAIR              DESPAIR
# 2      NaN                  NaN         NaN                  NaN
# 3      JOY                  JOY     DESPAIR              DESPAIR
# 4      JOY                  JOY     DESPAIR              DESPAIR
#
#   York Peppermint Patties           Dress     Day  DailyDish  Science  ESPN  \
# 0                     NaN             NaN     NaN        NaN      NaN   NaN
# 1                 DESPAIR  White and gold  Sunday        NaN      1.0   NaN
# 2                     NaN             NaN     NaN        NaN      NaN   NaN
# 3                 DESPAIR  White and gold  Sunday        NaN      1.0   NaN
# 4                     JOY  White and gold  Friday        NaN      1.0   NaN
#
#    Yahoo
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %% [markdown]
# ### 5 - clean `going out` column
# > tip : you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df['Going Out?'].unique()
# Out:
# array([nan, 'No', 'Yes'], dtype=object)

# %%
df['Going Out?'].isna().sum()
# Out:
# 110

# %%
df['Going Out?'] = df['Going Out?'].fillna('Maybe')

# %%
df['Going Out?'].value_counts()
# Out:
# No       2038
# Yes       312
# Maybe     110
# Name: Going Out?, dtype: int64

# %% [markdown]
# ### 6 - clean ` gender` column
# > tip : you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df['Gender'].unique()
# Out:
# array([nan, 'Male', 'Female', "I'd rather not say", 'Other'], dtype=object)

# %%
df['Gender'].isna().sum()
# Out:
# 41

# %%
df['Gender'] = df['Gender'].fillna("I'd rather not say")

# %%
df['Gender'].value_counts()
# Out:
# Male                  1467
# Female                 839
# I'd rather not say     124
# Other                   30
# Name: Gender, dtype: int64

# %% [markdown]
# ### 7 - clean ` age` column
# > tip : note the type of age column , and NaN values
#  - try to use `to_numeric`
#  - tip : you should choose which best value to put in place of these NaNs ( mean, median, ....etc)

# %%
df['Age'].unique()
# Out:
# array([nan, 44, 49, 40, 23, 53, 33, 43, 56, 64, 37, 59, 48, 54, 36, 45,
#        25, 34, 35, 38, 58, 50, 47, 16, 52, 63, 65, 41, 27, 31, 61, 46, 42,
#        62, 29, 39, 32, 28, 69, 67, 30, 22, 26, 51, 70, 24, 18, 19,
#        'Old enough', 57, 60, 66, 12, 'Many', 55, 72, '?', 21, 11, 'no', 9,
#        68, 20, 6, 10, 71, 90, 13, '45-55', 312, 99, 7, 'hahahahaha', 88,
#        39.4, 74, 102, 'older than dirt', 17, 15, 8, 75, '5u', 'Enough',
#        'See question 2', '24-50', 14, 'Over 50', 100, 76, 1000,
#        'sixty-nine', '46 Halloweens.', 'ancient', 77, 'OLD', 'old', 73,
#        70.5, 1, 'MY NAME JEFF', 4, '59 on the day after Halloween',
#        'old enough', 'your mom',
#        'I can remember when Java was a cool new language', '60+'],
#       dtype=object)

# %%
df['Age'] = pd.to_numeric(df['Age'] , errors = 'coerce')

# %%
df['Age'].isna().sum()
# Out:
# 108

# %%
df.Age[df['Age']>90]=np.nan
# Out:
# <ipython-input-30-1582d86ec7a9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Age[df['Age']>90]=np.nan

# %%
df['Age'].mean()
# Out:
# 41.9961210571185

# %%
df['Age'].median()
# Out:
# 41.0

# %% [markdown]
# > #### from the mean and the median of the age: Obviously they are almost equal

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df['Age'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### 8 - clean ` country` column
# > tip : note that country column has country names with different writing ways
#   - use fuzzywuzzy to deal with this problem
#   - you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df['Country'].unique()
# Out:
# array([nan, 'USA ', 'USA', 'us', 'usa', 'canada', 'Canada', 'Us', 'US',
#        'Murica', 'United States', 'uk', 'United Kingdom', 'united states',
#        'Usa', 'United States ', 'United staes',
#        'United States of America', 'UAE', 'England', 'UK', 'canada ',
#        'Mexico', 'United states', 'u.s.a.', 'USAUSAUSA', 'america', 35,
#        'france', 'United States of America ', 'U.S.A.', 'finland',
#        'unhinged states', 'Canada ', 'united states of america',
#        'US of A', 'Unites States', 'The United States', 'North Carolina ',
#        'Unied States', 'Netherlands', 'germany', 'Europe', 'Earth', 'U S',
#        'u.s.', 'U.K. ', 'Costa Rica', 'The United States of America',
#        'unite states', 'U.S.', 46, 'cascadia', 'Australia',
#        'insanity lately', 'Greece', 'USA? Hard to tell anymore..',
#        "'merica", 'usas', 'Pittsburgh', 45, 'United State', 32, 'France',
#        'australia', 'A', 'Can', 'Canae', 'New York', 'Trumpistan',
#        'Ireland', 'United Sates', 'Korea', 'California', 'Japan', 'USa',
#        'South africa',
#        'I pretend to be from Canada, but I am really from the United States.',
#        'Usa ', 'Uk', 'Iceland', 'Germany', 'Canada`', 'Scotland', 'UK ',
#        'Denmark', 'United Stated', 'France ', 'Switzerland',
#        'Ahem....Amerca', 'UD', 'Scotland ', 'South Korea', 'New Jersey',
#        'CANADA', 'Indonesia', 'United ststes', 'America',
#        'The Netherlands', 'United Statss', 'endland', 'Atlantis',
#        'murrika', 'USA! USA! USA!', 'USAA', 'Alaska', 'united States ',
#        'soviet canuckistan', 'N. America', 'Singapore', 'USSA', 'China',
#        'Taiwan', 'Ireland ', 'hong kong', 'spain', 'Sweden', 'Hong Kong',
#        'U.S. ', 'Narnia', 'u s a', 'United Statea', 'united ststes', 1,
#        'subscribe to dm4uz3 on youtube', 'United kingdom',
#        'USA USA USA!!!!', "I don't know anymore", 'Fear and Loathing'],
#       dtype=object)

# %%
df['Country'] = df['Country'].str.strip().str.lower()

# %%
countries = pd.Series(['usa', 'united states of america','america','united kingdom england', 'hong kong', 'china', 'sweden', 'spain',
                       'ireland', 'taiwan', 'singapore', 'netherlands',
                       'indonesia', 'south korea', 'switzerland', 'denmark', 'scotland', 'canada', 'iceland', 'south africa',
                       'japan', 'greece', 'costa rica', 'germany', 'finland', 'france', 'mexico'])

for country in countries:
    matches = process.extract(country, df['Country'], limit = df.shape[0])
    for potential_match in matches:
        if potential_match[1] >= 80:
            df.loc[df['Country'] == potential_match[0], 'Country'] = country

df['Country'].unique()
# Out:
# array([nan, 'usa', 'canada', 'murica', 'america', 'uk', 'uae',
#        'united kingdom england', 'mexico', 'u.s.a.', 'france', 'finland',
#        'north carolina', 'netherlands', 'germany', 'europe', 'earth',
#        'u.k.', 'costa rica', 'cascadia', 'australia', 'insanity lately',
#        'greece', 'usa? hard to tell anymore..', 'pittsburgh', 'canae',
#        'new york', 'trumpistan', 'iceland', 'south korea', 'california',
#        'japan', 'south africa', 'scotland', 'denmark', 'switzerland',
#        'ud', 'new jersey', 'indonesia', 'endland', 'atlantis', 'murrika',
#        'alaska', 'soviet canuckistan', 'singapore', 'china', 'taiwan',
#        'hong kong', 'spain', 'sweden', 'narnia', 'u s a',
#        'subscribe to dm4uz3 on youtube', "i don't know anymore",
#        'fear and loathing'], dtype=object)

# %%
df['Country'].value_counts()
# Out:
# usa                               1319
# america                            726
# canada                             226
# uk                                  18
# germany                             10
# u.s.a.                               8
# netherlands                          7
# australia                            7
# scotland                             5
# japan                                5
# iceland                              5
# mexico                               4
# switzerland                          3
# france                               3
# sweden                               2
# denmark                              2
# south korea                          2
# hong kong                            2
# china                                2
# narnia                               1
# spain                                1
# u s a                                1
# taiwan                               1
# ud                                   1
# singapore                            1
# soviet canuckistan                   1
# alaska                               1
# murrika                              1
# subscribe to dm4uz3 on youtube       1
# atlantis                             1
# endland                              1
# indonesia                            1
# new jersey                           1
# i don't know anymore                 1
# north carolina                       1
# murica                               1
# finland                              1
# south africa                         1
# europe                               1
# earth                                1
# u.k.                                 1
# costa rica                           1
# cascadia                             1
# insanity lately                      1
# greece                               1
# usa? hard to tell anymore..          1
# pittsburgh                           1
# canae                                1
# new york                             1
# trumpistan                           1
# united kingdom england               1
# california                           1
# uae                                  1
# fear and loathing                    1
# Name: Country, dtype: int64

# %%
mapping = {'murica':'usa', 'united states of america':'usa','america':'usa', 'u.s.a.':'usa',
'north carolina':'usa', 'usa? hard to tell anymore..':'usa', 'pittsburgh':'usa', 'new york':'usa', 'trumpistan':'usa',
          'california':'usa', 'ud':'usa', 'new jersey':'usa', 'endland':'uk', 'soviet canuckistan':'canada',
           'u s a':'usa', 'united kingdom england':'uk', 'u.k.':'uk', 'cascadia':'usa'}
df['Country'] = df['Country'].replace(mapping)

# %%
df.Country[~df['Country'].isin(['usa', 'uk','canada'])]='other'
# Out:
# <ipython-input-40-854fb8f5f5a8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Country[~df['Country'].isin(['usa', 'uk','canada'])]='other'

# %%
df['Country'] = df['Country'].str.upper()
df['Country'].value_counts()
# Out:
# USA       2064
# CANADA     227
# OTHER      148
# UK          21
# Name: Country, dtype: int64

# %% [markdown]
# ### 9 - clean ` area` column
# > tip : area column has the same problem as country columns , but looking at all it's unique values may give us another way to deal with it rather than try to fix it

# %%
df['Area'].nunique()
# Out:
# 511

# %% [markdown]
# > #### Area column is not important in the survery due to the extreme difference

# %%
df.drop('Area', axis="columns", inplace=True)

# %%
df.head()
# Out:
#   Going Out?              Gender        Age Country 100 Grand Bar  \
# 0      Maybe  I'd rather not say  41.996121   OTHER           NaN
# 1         No                Male  44.000000     USA           MEH
# 2      Maybe                Male  49.000000     USA           NaN
# 3         No                Male  40.000000     USA           MEH
# 4         No                Male  23.000000     USA           JOY
#
#   Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Any full-sized candy bar Black Jacks Bonkers (the candy)  \
# 0                      NaN         NaN                 NaN
# 1                      JOY         MEH             DESPAIR
# 2                      NaN         NaN                 NaN
# 3                      JOY         MEH                 MEH
# 4                      JOY     DESPAIR                 MEH
#
#   Bonkers (the board game) Bottle Caps Box'o'Raisins Broken glow stick  \
# 0                      NaN         NaN           NaN               NaN
# 1                  DESPAIR     DESPAIR       DESPAIR           DESPAIR
# 2                      NaN         NaN           NaN               NaN
# 3                  DESPAIR         MEH       DESPAIR           DESPAIR
# 4                  DESPAIR         MEH       DESPAIR           DESPAIR
#
#   Butterfinger Cadbury Creme Eggs Candy Corn  \
# 0          NaN                NaN        NaN
# 1      DESPAIR                MEH        MEH
# 2          NaN                NaN        NaN
# 3          MEH                MEH    DESPAIR
# 4          MEH                MEH    DESPAIR
#
#   Candy that is clearly just the stuff given out for free at restaurants  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                            DESPAIR
#
#   Caramellos Cash, or other forms of legal tender Chardonnay  \
# 0        NaN                                  NaN        NaN
# 1        MEH                                  JOY        MEH
# 2        NaN                                  NaN        NaN
# 3        MEH                                  JOY        MEH
# 4        JOY                                  MEH        JOY
#
#   Chick-o-Sticks (we don’t know what that is) Chiclets Coffee Crisp  \
# 0                                         NaN      NaN          NaN
# 1                                     DESPAIR  DESPAIR      DESPAIR
# 2                                         NaN      NaN          NaN
# 3                                         JOY      MEH      DESPAIR
# 4                                     DESPAIR  DESPAIR          MEH
#
#   Creepy Religious comics/Chick Tracts Dental paraphenalia Dots Dove Bars  \
# 0                                  NaN                 NaN  NaN       NaN
# 1                              DESPAIR             DESPAIR  MEH       JOY
# 2                                  NaN                 NaN  NaN       NaN
# 3                              DESPAIR             DESPAIR  JOY       JOY
# 4                              DESPAIR             DESPAIR  MEH       JOY
#
#   Fuzzy Peaches Generic Brand Acetaminophen Glow sticks Goo Goo Clusters  \
# 0           NaN                         NaN         NaN              NaN
# 1       DESPAIR                     DESPAIR     DESPAIR          DESPAIR
# 2           NaN                         NaN         NaN              NaN
# 3           MEH                         MEH         JOY              JOY
# 4       DESPAIR                     DESPAIR     DESPAIR              MEH
#
#   Good N' Plenty Gum from baseball cards Gummy Bears straight up Hard Candy  \
# 0            NaN                     NaN                     NaN        NaN
# 1            MEH                 DESPAIR                     MEH        MEH
# 2            NaN                     NaN                     NaN        NaN
# 3            MEH                 DESPAIR                     JOY        MEH
# 4            MEH                 DESPAIR                     JOY        MEH
#
#   Healthy Fruit Heath Bar Hershey's Dark Chocolate Hershey’s Milk Chocolate  \
# 0           NaN       NaN                      NaN                      NaN
# 1       DESPAIR       MEH                      JOY                      JOY
# 2           NaN       NaN                      NaN                      NaN
# 3           MEH   DESPAIR                      MEH                      MEH
# 4       DESPAIR   DESPAIR                      JOY                      MEH
#
#   Hershey's Kisses Hugs (actual physical hugs) Jolly Rancher (bad flavor)  \
# 0              NaN                         NaN                        NaN
# 1              MEH                     DESPAIR                    DESPAIR
# 2              NaN                         NaN                        NaN
# 3              MEH                         MEH                        MEH
# 4              MEH                     DESPAIR                        MEH
#
#   Jolly Ranchers (good flavor) JoyJoy (Mit Iodine!) Junior Mints Senior Mints  \
# 0                          NaN                  NaN          NaN          NaN
# 1                          MEH              DESPAIR      DESPAIR      DESPAIR
# 2                          NaN                  NaN          NaN          NaN
# 3                          MEH              DESPAIR      DESPAIR      DESPAIR
# 4                          JOY                  MEH          JOY      DESPAIR
#
#   Kale smoothie Kinder Happy Hippo Kit Kat LaffyTaffy LemonHeads  \
# 0           NaN                NaN     NaN        NaN        NaN
# 1       DESPAIR            DESPAIR     JOY    DESPAIR        MEH
# 2           NaN                NaN     NaN        NaN        NaN
# 3       DESPAIR                MEH     MEH        JOY        JOY
# 4       DESPAIR                JOY     JOY        JOY        JOY
#
#   Licorice (not black) Licorice (yes black) Lindt Truffle Lollipops     Mars  \
# 0                  NaN                  NaN           NaN       NaN      NaN
# 1                  MEH                  JOY           MEH   DESPAIR  DESPAIR
# 2                  NaN                  NaN           NaN       NaN      NaN
# 3                  MEH                  JOY           JOY   DESPAIR      JOY
# 4                  MEH              DESPAIR           JOY       MEH      MEH
#
#   Maynards Mike and Ike Milk Duds Milky Way Regular M&Ms Peanut M&M’s  \
# 0      NaN          NaN       NaN       NaN          NaN          NaN
# 1  DESPAIR          MEH       MEH       JOY          JOY          MEH
# 2      NaN          NaN       NaN       NaN          NaN          NaN
# 3      MEH          MEH   DESPAIR       JOY          MEH          JOY
# 4  DESPAIR          MEH       MEH       JOY          JOY          JOY
#
#   Blue M&M's Red M&M's Green Party M&M's Independent M&M's  \
# 0        NaN       NaN               NaN               NaN
# 1        JOY       JOY               JOY               JOY
# 2        NaN       NaN               NaN               NaN
# 3        MEH       MEH               MEH               MEH
# 4        JOY       JOY               JOY               JOY
#
#   Abstained from M&M'ing. Minibags of chips Mint Kisses Mint Juleps  \
# 0                     NaN               NaN         NaN         NaN
# 1                 DESPAIR           DESPAIR         MEH     DESPAIR
# 2                     NaN               NaN         NaN         NaN
# 3                     MEH           DESPAIR     DESPAIR         MEH
# 4                     MEH           DESPAIR         JOY         JOY
#
#   Mr. Goodbar Necco Wafers    Nerds Nestle Crunch Now'n'Laters    Peeps  \
# 0         NaN          NaN      NaN           NaN          NaN      NaN
# 1     DESPAIR      DESPAIR  DESPAIR           JOY      DESPAIR  DESPAIR
# 2         NaN          NaN      NaN           NaN          NaN      NaN
# 3         MEH      DESPAIR      MEH           MEH          MEH  DESPAIR
# 4         MEH      DESPAIR      JOY           JOY          JOY      MEH
#
#    Pencils Pixy Stix Real Housewives of Orange County Season 9 Blue-Ray  \
# 0      NaN       NaN                                                NaN
# 1  DESPAIR   DESPAIR                                            DESPAIR
# 2      NaN       NaN                                                NaN
# 3  DESPAIR   DESPAIR                                            DESPAIR
# 4  DESPAIR       JOY                                            DESPAIR
#
#   Reese’s Peanut Butter Cups Reese's Pieces Reggie Jackson Bar Rolos  \
# 0                        NaN            NaN                NaN   NaN
# 1                        JOY            JOY            DESPAIR   JOY
# 2                        NaN            NaN                NaN   NaN
# 3                        JOY            MEH                MEH   MEH
# 4                        JOY            JOY                MEH   JOY
#
#   Sandwich-sized bags filled with BooBerry Crunch Skittles  \
# 0                                             NaN      NaN
# 1                                         DESPAIR  DESPAIR
# 2                                             NaN      NaN
# 3                                         DESPAIR  DESPAIR
# 4                                             NaN      JOY
#
#   Smarties (American) Smarties (Commonwealth) Snickers  \
# 0                 NaN                     NaN      NaN
# 1             DESPAIR                 DESPAIR      MEH
# 2                 NaN                     NaN      NaN
# 3             DESPAIR                     MEH      JOY
# 4                 JOY                 DESPAIR      NaN
#
#   Sourpatch Kids (i.e. abominations of nature) Spotted Dick Starburst  \
# 0                                          NaN          NaN       NaN
# 1                                      DESPAIR      DESPAIR       MEH
# 2                                          NaN          NaN       NaN
# 3                                          MEH      DESPAIR       MEH
# 4                                          MEH      DESPAIR       JOY
#
#   Sweet Tarts Swedish Fish Sweetums (a friend to diabetes)   Take 5 Tic Tacs  \
# 0         NaN          NaN                             NaN      NaN      NaN
# 1     DESPAIR          MEH                         DESPAIR  DESPAIR  DESPAIR
# 2         NaN          NaN                             NaN      NaN      NaN
# 3         MEH          JOY                             MEH      JOY      MEH
# 4         JOY          MEH                         DESPAIR      MEH  DESPAIR
#
#   Those odd marshmallow circus peanut things Three Musketeers  \
# 0                                        NaN              NaN
# 1                                    DESPAIR              JOY
# 2                                        NaN              NaN
# 3                                    DESPAIR          DESPAIR
# 4                                    DESPAIR              JOY
#
#   Tolberone something or other Trail Mix Twix  \
# 0                          NaN       NaN  NaN
# 1                          JOY   DESPAIR  JOY
# 2                          NaN       NaN  NaN
# 3                          JOY       MEH  JOY
# 4                          JOY   DESPAIR  JOY
#
#   Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# 4                                                MEH
#
#    Vicodin Whatchamacallit Bars White Bread Whole Wheat anything  \
# 0      NaN                  NaN         NaN                  NaN
# 1  DESPAIR              DESPAIR     DESPAIR              DESPAIR
# 2      NaN                  NaN         NaN                  NaN
# 3      JOY                  JOY     DESPAIR              DESPAIR
# 4      JOY                  JOY     DESPAIR              DESPAIR
#
#   York Peppermint Patties           Dress     Day  DailyDish  Science  ESPN  \
# 0                     NaN             NaN     NaN        NaN      NaN   NaN
# 1                 DESPAIR  White and gold  Sunday        NaN      1.0   NaN
# 2                     NaN             NaN     NaN        NaN      NaN   NaN
# 3                 DESPAIR  White and gold  Sunday        NaN      1.0   NaN
# 4                     JOY  White and gold  Friday        NaN      1.0   NaN
#
#    Yahoo
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %% [markdown]
# ### 10 - clean ` Q6` columns
# >- tip : Q6 has all kinds of chocolate bars and questions with three distinct options to choose from (Joy, Meh, Despair).
# - so all the column that has Q6 is a candy name , so you should go through all these column and you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df = df.drop(df[df.iloc[:,4:-6].isnull().all(axis=1)].index)

# %%
df.shape
# Out:
# (1803, 113)

# %%
df['100 Grand Bar'].unique()
# Out:
# array(['MEH', 'JOY', nan, 'DESPAIR'], dtype=object)

# %%
df.iloc[:,4:-6]=df.iloc[:,4:-6].fillna('MEH')

# %%
df.iloc[:,4:-6].isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### 11 - clean ` dress` column
# >tip : you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df['Dress'].unique()
# Out:
# array(['White and gold', nan, 'Blue and black'], dtype=object)

# %%
df['Dress'].value_counts()
# Out:
# White and gold    1079
# Blue and black     634
# Name: Dress, dtype: int64

# %%
df['Dress'] = df['Dress'].fillna('unknown')

# %%
df['Dress'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### 12 - clean ` day` column
# >tip : you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df['Day'].unique()
# Out:
# array(['Sunday', 'Friday', nan], dtype=object)

# %%
df['Day'] = df['Day'].fillna('Friday')

# %%
df['Day'].isna().sum()
# Out:
# 0

# %%
df['Day'].value_counts()
# Out:
# Friday    1160
# Sunday     643
# Name: Day, dtype: int64

# %% [markdown]
# > #### I would make the last four columns in a columns named Media

# %% [markdown]
# ### 11 - Clean ` Media` column

# %%
media = df.iloc[:,-4:]
for i in media.columns:
    media.loc[media[i] == 1.0, i] = i
df['Media'] = media[media.columns].apply(lambda x: ''.join(x.dropna().astype(str)),axis=1)
df['Media']=df['Media'].astype('category')
df.drop(['DailyDish', 'Science', 'ESPN', 'Yahoo'] , axis="columns", inplace=True)
df.loc[df['Media'] == '', 'Media'] = df['Media'].mode().iloc[0]
df.head()
# Out:
#   Going Out? Gender        Age Country 100 Grand Bar  \
# 1         No   Male  44.000000     USA           MEH
# 3         No   Male  40.000000     USA           MEH
# 4         No   Male  23.000000     USA           JOY
# 5         No   Male  41.996121   OTHER           JOY
# 7         No   Male  33.000000  CANADA           JOY
#
#   Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                            DESPAIR
# 3                                            DESPAIR
# 4                                            DESPAIR
# 5                                            DESPAIR
# 7                                            DESPAIR
#
#   Any full-sized candy bar Black Jacks Bonkers (the candy)  \
# 1                      JOY         MEH             DESPAIR
# 3                      JOY         MEH                 MEH
# 4                      JOY     DESPAIR                 MEH
# 5                      JOY         MEH                 MEH
# 7                      JOY     DESPAIR             DESPAIR
#
#   Bonkers (the board game) Bottle Caps Box'o'Raisins Broken glow stick  \
# 1                  DESPAIR     DESPAIR       DESPAIR           DESPAIR
# 3                  DESPAIR         MEH       DESPAIR           DESPAIR
# 4                  DESPAIR         MEH       DESPAIR           DESPAIR
# 5                      MEH         MEH           MEH           DESPAIR
# 7                      MEH         JOY           MEH               JOY
#
#   Butterfinger Cadbury Creme Eggs Candy Corn  \
# 1      DESPAIR                MEH        MEH
# 3          MEH                MEH    DESPAIR
# 4          MEH                MEH    DESPAIR
# 5          JOY            DESPAIR        MEH
# 7          JOY                JOY        JOY
#
#   Candy that is clearly just the stuff given out for free at restaurants  \
# 1                                            DESPAIR
# 3                                            DESPAIR
# 4                                            DESPAIR
# 5                                                MEH
# 7                                            DESPAIR
#
#   Caramellos Cash, or other forms of legal tender Chardonnay  \
# 1        MEH                                  JOY        MEH
# 3        MEH                                  JOY        MEH
# 4        JOY                                  MEH        JOY
# 5        JOY                                  JOY        JOY
# 7        JOY                                  JOY        JOY
#
#   Chick-o-Sticks (we don’t know what that is) Chiclets Coffee Crisp  \
# 1                                     DESPAIR  DESPAIR      DESPAIR
# 3                                         JOY      MEH      DESPAIR
# 4                                     DESPAIR  DESPAIR          MEH
# 5                                         MEH      MEH          JOY
# 7                                     DESPAIR      MEH          MEH
#
#   Creepy Religious comics/Chick Tracts Dental paraphenalia Dots Dove Bars  \
# 1                              DESPAIR             DESPAIR  MEH       JOY
# 3                              DESPAIR             DESPAIR  JOY       JOY
# 4                              DESPAIR             DESPAIR  MEH       JOY
# 5                              DESPAIR                 MEH  MEH       JOY
# 7                              DESPAIR             DESPAIR  MEH       MEH
#
#   Fuzzy Peaches Generic Brand Acetaminophen Glow sticks Goo Goo Clusters  \
# 1       DESPAIR                     DESPAIR     DESPAIR          DESPAIR
# 3           MEH                         MEH         JOY              JOY
# 4       DESPAIR                     DESPAIR     DESPAIR              MEH
# 5           MEH                     DESPAIR         MEH              JOY
# 7           JOY                     DESPAIR     DESPAIR          DESPAIR
#
#   Good N' Plenty Gum from baseball cards Gummy Bears straight up Hard Candy  \
# 1            MEH                 DESPAIR                     MEH        MEH
# 3            MEH                 DESPAIR                     JOY        MEH
# 4            MEH                 DESPAIR                     JOY        MEH
# 5            MEH                 DESPAIR                     MEH        MEH
# 7        DESPAIR                 DESPAIR                     JOY    DESPAIR
#
#   Healthy Fruit Heath Bar Hershey's Dark Chocolate Hershey’s Milk Chocolate  \
# 1       DESPAIR       MEH                      JOY                      JOY
# 3           MEH   DESPAIR                      MEH                      MEH
# 4       DESPAIR   DESPAIR                      JOY                      MEH
# 5           MEH       JOY                      JOY                      MEH
# 7       DESPAIR   DESPAIR                      JOY                      MEH
#
#   Hershey's Kisses Hugs (actual physical hugs) Jolly Rancher (bad flavor)  \
# 1              MEH                     DESPAIR                    DESPAIR
# 3              MEH                         MEH                        MEH
# 4              MEH                     DESPAIR                        MEH
# 5              MEH                         MEH                        MEH
# 7              MEH                     DESPAIR                    DESPAIR
#
#   Jolly Ranchers (good flavor) JoyJoy (Mit Iodine!) Junior Mints Senior Mints  \
# 1                          MEH              DESPAIR      DESPAIR      DESPAIR
# 3                          MEH              DESPAIR      DESPAIR      DESPAIR
# 4                          JOY                  MEH          JOY      DESPAIR
# 5                          MEH                  MEH          JOY          MEH
# 7                      DESPAIR              DESPAIR      DESPAIR      DESPAIR
#
#   Kale smoothie Kinder Happy Hippo Kit Kat LaffyTaffy LemonHeads  \
# 1       DESPAIR            DESPAIR     JOY    DESPAIR        MEH
# 3       DESPAIR                MEH     MEH        JOY        JOY
# 4       DESPAIR                JOY     JOY        JOY        JOY
# 5       DESPAIR                MEH     JOY        MEH        MEH
# 7       DESPAIR            DESPAIR     MEH        MEH        JOY
#
#   Licorice (not black) Licorice (yes black) Lindt Truffle Lollipops     Mars  \
# 1                  MEH                  JOY           MEH   DESPAIR  DESPAIR
# 3                  MEH                  JOY           JOY   DESPAIR      JOY
# 4                  MEH              DESPAIR           JOY       MEH      MEH
# 5                  MEH                  MEH           JOY       MEH      JOY
# 7                  MEH              DESPAIR       DESPAIR       MEH      JOY
#
#   Maynards Mike and Ike Milk Duds Milky Way Regular M&Ms Peanut M&M’s  \
# 1  DESPAIR          MEH       MEH       JOY          JOY          MEH
# 3      MEH          MEH   DESPAIR       JOY          MEH          JOY
# 4  DESPAIR          MEH       MEH       JOY          JOY          JOY
# 5      MEH          JOY       JOY       JOY          JOY          JOY
# 7      JOY          JOY       JOY       JOY          JOY          JOY
#
#   Blue M&M's Red M&M's Green Party M&M's Independent M&M's  \
# 1        JOY       JOY               JOY               JOY
# 3        MEH       MEH               MEH               MEH
# 4        JOY       JOY               JOY               JOY
# 5        JOY       JOY               MEH               MEH
# 7        JOY       JOY               JOY               MEH
#
#   Abstained from M&M'ing. Minibags of chips Mint Kisses Mint Juleps  \
# 1                 DESPAIR           DESPAIR         MEH     DESPAIR
# 3                     MEH           DESPAIR     DESPAIR         MEH
# 4                     MEH           DESPAIR         JOY         JOY
# 5                     MEH               JOY         JOY         JOY
# 7                 DESPAIR               JOY     DESPAIR     DESPAIR
#
#   Mr. Goodbar Necco Wafers    Nerds Nestle Crunch Now'n'Laters    Peeps  \
# 1     DESPAIR      DESPAIR  DESPAIR           JOY      DESPAIR  DESPAIR
# 3         MEH      DESPAIR      MEH           MEH          MEH  DESPAIR
# 4         MEH      DESPAIR      JOY           JOY          JOY      MEH
# 5         JOY          MEH      JOY           MEH          MEH  DESPAIR
# 7         MEH          MEH      JOY           JOY          MEH  DESPAIR
#
#    Pencils Pixy Stix Real Housewives of Orange County Season 9 Blue-Ray  \
# 1  DESPAIR   DESPAIR                                            DESPAIR
# 3  DESPAIR   DESPAIR                                            DESPAIR
# 4  DESPAIR       JOY                                            DESPAIR
# 5  DESPAIR       MEH                                            DESPAIR
# 7  DESPAIR   DESPAIR                                            DESPAIR
#
#   Reese’s Peanut Butter Cups Reese's Pieces Reggie Jackson Bar Rolos  \
# 1                        JOY            JOY            DESPAIR   JOY
# 3                        JOY            MEH                MEH   MEH
# 4                        JOY            JOY                MEH   JOY
# 5                        JOY            JOY            DESPAIR   JOY
# 7                        JOY            JOY                MEH   JOY
#
#   Sandwich-sized bags filled with BooBerry Crunch Skittles  \
# 1                                         DESPAIR  DESPAIR
# 3                                         DESPAIR  DESPAIR
# 4                                             MEH      JOY
# 5                                         DESPAIR      JOY
# 7                                         DESPAIR      JOY
#
#   Smarties (American) Smarties (Commonwealth) Snickers  \
# 1             DESPAIR                 DESPAIR      MEH
# 3             DESPAIR                     MEH      JOY
# 4                 JOY                 DESPAIR      MEH
# 5                 JOY                     JOY      JOY
# 7                 MEH                     JOY      MEH
#
#   Sourpatch Kids (i.e. abominations of nature) Spotted Dick Starburst  \
# 1                                      DESPAIR      DESPAIR       MEH
# 3                                          MEH      DESPAIR       MEH
# 4                                          MEH      DESPAIR       JOY
# 5                                      DESPAIR      DESPAIR       MEH
# 7                                          JOY      DESPAIR       MEH
#
#   Sweet Tarts Swedish Fish Sweetums (a friend to diabetes)   Take 5 Tic Tacs  \
# 1     DESPAIR          MEH                         DESPAIR  DESPAIR  DESPAIR
# 3         MEH          JOY                             MEH      JOY      MEH
# 4         JOY          MEH                         DESPAIR      MEH  DESPAIR
# 5         MEH          MEH                             MEH      MEH      MEH
# 7         JOY          JOY                             MEH      MEH  DESPAIR
#
#   Those odd marshmallow circus peanut things Three Musketeers  \
# 1                                    DESPAIR              JOY
# 3                                    DESPAIR          DESPAIR
# 4                                    DESPAIR              JOY
# 5                                    DESPAIR              JOY
# 7                                    DESPAIR              JOY
#
#   Tolberone something or other Trail Mix Twix  \
# 1                          JOY   DESPAIR  JOY
# 3                          JOY       MEH  JOY
# 4                          JOY   DESPAIR  JOY
# 5                          JOY       MEH  JOY
# 7                          MEH   DESPAIR  JOY
#
#   Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 1                                            DESPAIR
# 3                                            DESPAIR
# 4                                                MEH
# 5                                            DESPAIR
# 7                                                JOY
#
#    Vicodin Whatchamacallit Bars White Bread Whole Wheat anything  \
# 1  DESPAIR              DESPAIR     DESPAIR              DESPAIR
# 3      JOY                  JOY     DESPAIR              DESPAIR
# 4      JOY                  JOY     DESPAIR              DESPAIR
# 5  DESPAIR                  JOY     DESPAIR              DESPAIR
# 7      MEH              DESPAIR     DESPAIR              DESPAIR
#
#   York Peppermint Patties           Dress     Day    Media
# 1                 DESPAIR  White and gold  Sunday  Science
# 3                 DESPAIR  White and gold  Sunday  Science
# 4                     JOY  White and gold  Friday  Science
# 5                     JOY         unknown  Friday  Science
# 7                 DESPAIR  Blue and black  Friday  Science

# %% [markdown]
# ### 13 - check
# > after finish cleaning you should make sure your data is clean and that :
# - there is no wrong data type
# - there is no NaN values
# - all the column are cleaing and ready for the next step `EDA`

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df['Age'] = df['Age'].astype(int)

# %%
df.head(1)
# Out:
#   Going Out? Gender  Age Country 100 Grand Bar  \
# 1         No   Male   44     USA           MEH
#
#   Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                            DESPAIR
#
#   Any full-sized candy bar Black Jacks Bonkers (the candy)  \
# 1                      JOY         MEH             DESPAIR
#
#   Bonkers (the board game) Bottle Caps Box'o'Raisins Broken glow stick  \
# 1                  DESPAIR     DESPAIR       DESPAIR           DESPAIR
#
#   Butterfinger Cadbury Creme Eggs Candy Corn  \
# 1      DESPAIR                MEH        MEH
#
#   Candy that is clearly just the stuff given out for free at restaurants  \
# 1                                            DESPAIR
#
#   Caramellos Cash, or other forms of legal tender Chardonnay  \
# 1        MEH                                  JOY        MEH
#
#   Chick-o-Sticks (we don’t know what that is) Chiclets Coffee Crisp  \
# 1                                     DESPAIR  DESPAIR      DESPAIR
#
#   Creepy Religious comics/Chick Tracts Dental paraphenalia Dots Dove Bars  \
# 1                              DESPAIR             DESPAIR  MEH       JOY
#
#   Fuzzy Peaches Generic Brand Acetaminophen Glow sticks Goo Goo Clusters  \
# 1       DESPAIR                     DESPAIR     DESPAIR          DESPAIR
#
#   Good N' Plenty Gum from baseball cards Gummy Bears straight up Hard Candy  \
# 1            MEH                 DESPAIR                     MEH        MEH
#
#   Healthy Fruit Heath Bar Hershey's Dark Chocolate Hershey’s Milk Chocolate  \
# 1       DESPAIR       MEH                      JOY                      JOY
#
#   Hershey's Kisses Hugs (actual physical hugs) Jolly Rancher (bad flavor)  \
# 1              MEH                     DESPAIR                    DESPAIR
#
#   Jolly Ranchers (good flavor) JoyJoy (Mit Iodine!) Junior Mints Senior Mints  \
# 1                          MEH              DESPAIR      DESPAIR      DESPAIR
#
#   Kale smoothie Kinder Happy Hippo Kit Kat LaffyTaffy LemonHeads  \
# 1       DESPAIR            DESPAIR     JOY    DESPAIR        MEH
#
#   Licorice (not black) Licorice (yes black) Lindt Truffle Lollipops     Mars  \
# 1                  MEH                  JOY           MEH   DESPAIR  DESPAIR
#
#   Maynards Mike and Ike Milk Duds Milky Way Regular M&Ms Peanut M&M’s  \
# 1  DESPAIR          MEH       MEH       JOY          JOY          MEH
#
#   Blue M&M's Red M&M's Green Party M&M's Independent M&M's  \
# 1        JOY       JOY               JOY               JOY
#
#   Abstained from M&M'ing. Minibags of chips Mint Kisses Mint Juleps  \
# 1                 DESPAIR           DESPAIR         MEH     DESPAIR
#
#   Mr. Goodbar Necco Wafers    Nerds Nestle Crunch Now'n'Laters    Peeps  \
# 1     DESPAIR      DESPAIR  DESPAIR           JOY      DESPAIR  DESPAIR
#
#    Pencils Pixy Stix Real Housewives of Orange County Season 9 Blue-Ray  \
# 1  DESPAIR   DESPAIR                                            DESPAIR
#
#   Reese’s Peanut Butter Cups Reese's Pieces Reggie Jackson Bar Rolos  \
# 1                        JOY            JOY            DESPAIR   JOY
#
#   Sandwich-sized bags filled with BooBerry Crunch Skittles  \
# 1                                         DESPAIR  DESPAIR
#
#   Smarties (American) Smarties (Commonwealth) Snickers  \
# 1             DESPAIR                 DESPAIR      MEH
#
#   Sourpatch Kids (i.e. abominations of nature) Spotted Dick Starburst  \
# 1                                      DESPAIR      DESPAIR       MEH
#
#   Sweet Tarts Swedish Fish Sweetums (a friend to diabetes)   Take 5 Tic Tacs  \
# 1     DESPAIR          MEH                         DESPAIR  DESPAIR  DESPAIR
#
#   Those odd marshmallow circus peanut things Three Musketeers  \
# 1                                    DESPAIR              JOY
#
#   Tolberone something or other Trail Mix Twix  \
# 1                          JOY   DESPAIR  JOY
#
#   Vials of pure high fructose corn syrup, for main-lining into your vein  \
# 1                                            DESPAIR
#
#    Vicodin Whatchamacallit Bars White Bread Whole Wheat anything  \
# 1  DESPAIR              DESPAIR     DESPAIR              DESPAIR
#
#   York Peppermint Patties           Dress     Day    Media
# 1                 DESPAIR  White and gold  Sunday  Science

# %%
df.shape
# Out:
# (1803, 110)

# %% [markdown]
# ### 14 - write a summary about all the cleaning steps
# > #### clean each column from invalid data.
# > #### fill the NaN values in each column with the suitable value.
# > #### drop some columns and rows that was not important and the survery are not affected by them.
# > #### overall there are `110` rows and `1803` columns.
# > #### there are about `103` columns which are the main candy columns.
# > #### the last `4` columns I mixed them into a column called `Media`.
